# %%
SET Lab
1.) เซตต่อไปนี้เป็นเซตจำกัดหรือ เซตไม่จำกัด
- เซตของเส้นตรงที่ขนานกับแกน Y
	ตอบ เซตไม่จำกัด
- เซตของจำนวนพนักงานในบริษัท
	ตอบ เซตจำกัด
- เซตของไฟฟ้าที่ใช้ในบริษัทในแต่ละเดือน
	ตอบ เซตจำกัด
- เซตของค่าใช้จ่ายแต่ละส่วนในบริษัท
	ตอบ เซตจำกัด

2.) เขียนสมาชิกของเซตต่อไปนี้
- A ={x| x^2 - 1 = 0}
	ตอบ {-1,1}
- B = {x| x เป็นตัวอักษรของคำว่า “probability”}
	ตอบ {p,r,o,b,a,i,l,y}
- C = {x | x เป็นจำนวนเดือนใน 1 ปี}
	ตอบ {12}

3.) A = {1,2} B = {1,2,3,4} 
C ={3,4} D = {4,5,6,7}

A ⊆ B  	ตอบ ถูก
A = C 	ตอบ ผิด
B ~ D  	ตอบ ถูก
D ⊆ C 	ตอบ ผิด
C ⊆ D 	ตอบ ผิด
A ≠ B  	ตอบ ถูก

4.) A = {1,2,3} B = {3,4,5,6,7}
C = {5,7,9} U= {1,2, …, 10}
เขียนสมาชิกเซตต่อไปนี้
A ∪ B ∪ C = {1,2,3,4,5,6,7,9}
A ∩ B ∩ C = {}
(B ∪ C)   = {1,2,8,10}
(A-B)'   = {3,4,5,6,7,8,9,10}

เปรียบเทียบระหว่าง 2 เซตนี้
(A ∩ C) ไม่เท่ากับ  A' ∪ C'    ต้อง (A ∩ C)’ เท่ากับ  A'c' ∪ C'
(A ∩ B) ∪ C = (A U C) ∩ (B U C)

Factorial lab
5!		= 120

5! x 3! / 4!	= 30

6! - 5! + 3!	= 606

19! / (15! x 4!)	= 3876

10! / 7!		= 720

3! x 4! x 6! / (5! x 2!)	= 432

ถ้าเด็กผู้ชาย 3 คนและ เด็กผู้หญิง 5 คน นั่งเป็นแถวตามลำดับอย่างสุ่ม
จงหาจำนวนเหตุการณ์ที่เด็กผู้ชายนั่งไม่ติดกัน
	ตอบ	จัด ญ 5 คนไม่รวม ช ได้ = 5!
		จัด ช ลง ที่ว่าง ได้ P6,3 
		จะได้ 5! x (6!/3!) = 14,400 วิธี

จงหาจำนวนเหตุการณ์ที่เด็กผู้หญิงนั่งไม่ติดกัน
ตอบ 	0 วิธี
จงหาจำนวนเหตุการณ์ที่เด็กผู้ชายนั่งหัวแถว
ตอบ 	เลือกคนนั่งหัวแถว ช = 3
	จัดคนในแถว 7 คน = 7!
	จะได้ 3 x 7! =15,120 วิธี
จงหาจำนวนเหตุการณ์ที่เด็กผู้หญิงนั่งติดกันเสมอ
ตอบ	ให้ ญ เป็นตำแหน่งเดียวกัน 4!
	ให้ ญ สลับกันเอง 5!
	จะได้ 4! x 5! = 2,880 วิธี
จงหาจำนวนเหตุการณ์ที่เด็กผู้ชายทุกคนหรือเด็กผู้หญิงทุกคนนั่งติดกัน
ตอบ	ให้ ช เป็นตำแหน่งเดียวกัน 6!
		ให้ ช สลับกันเอง 3!
		จะได้ 3! x 6! = 4,320 วิธี
		ดังนั้นจะได้ 4,320+2,880 = 7,200 วิธี

สำนักงานแห่งหนึ่งมีพนักงานเป็นชาย 6 หญิง 3 ต้องการสุ่มเลือกพนักงาน 3 คนเพื่อไปทำงานนอกสถานที่
จงหาจำนวนเหตุการณ์ที่เลือกพนักงานแล้วได้พนักงานเป็นชายทั้งหมด
ตอบ	เลือก ช 3 จาก 6 , ญ 0 จาก 3 = 6C3
= 6! / (3! * 3!)
= 20 
จงหาจำนวนเหตุการณ์ที่เลือกพนักงานแล้วได้พนักงานชาย 2 หญิง 1
ตอบ	เลือก ช 2 จาก 6 , ญ 1 จาก 3 = 6C2 * 3C1
= (6!/(4!*2!)) * (3!/2!)
= 45 
จงหาจำนวนเหตุการณ์ที่เลือกพนักงานแล้วได้พนักงานเป็น หญิง 2 ชาย 1
	ตอบ	เลือก ช 1 จาก 6 , ญ 2 จาก 3 = 6C1 * 3C2
= (6!/5!) * (3!/2!)= 45 

Probability Lab
จงหาค่าดังต่อไปนี้
1.จงหาวิธีในการจัดอักษรคำว่า construction ว่ามีทั้งหมดกี่วิธี
ตอบ  	c=2, o=2, n=2, s=1, t=2, r=1, u=1, i=1
	ดังนั้น 12!/(2!2!2!1!2!1!1!1!) = 29,937,600 วิธี

2. จงอธิบายและยกตัวอย่างเหตุการณ์ ของ 5P2  และ 20P15
ตอบ	การนำสิ่งของที่มีลักษณะที่แตกต่างกันทั้งหมดมาจัดเรียงสับเปลี่ยน
โดยลำดับของสิ่งของมีความสำคัญ เช่น 5P2 จะสร้างเลข 2 หลัก
จากตัวเลข 1, 2, 3, 4 ,5 ได้กี่จำนวน , 20P15 มีหนังสือที่เเตกต่างกัน 20 เล่ม
ต้องการนำหนังสือมา 15 เล่มเพื่อจัดเรียงเป็นเเถวบนชั้นจะจัดได้กี่วิธี

3. จงอธิบายและยกตัวอย่างเหตุการณ์ของ 5C2 และ 20C15
ตอบ	การนำสิ่งของที่มีความแตกต่างกันทั้งหมดหรือเพียงบางส่วนมาจัดหมู่ 
โดยไม่ถือตำแหน่งหรือลำดับก่อนหลังเป็นสำคัญ 
เช่น 5C2 วิธีเลือกนักเรียน 2 คนจากกลุ่มนักเรียน 5 คนนั้นมีทั้งหมดกี่วิธี 
,20C15 กล่องใบหนึ่งมีลูกบอลทั้งหมด 20 ลูก เลือกลูกบอล 15 ลูก มีกี่วิธี

4. จงอธิบายและยกเหตุการณ์ของการจัดกลุ่มซ้ำ ตามสูตร 15!/(1!2!3!4!5!)
	ตอบ	การนำสิ่งของทั้งหมด 15 อัน โดยจะแบ่งของที่เหมือนกันได้เป็น 5 กลุ่ม 
กลุ่มที่ 1 = 1 อัน , กลุ่มที่ 2 = 2 อัน ,กลุ่มที่ 3 = 3 อัน ,กลุ่มที่ 4 = 4 อัน,
กลุ่มที่ 5 = 5 อัน
เช่น กล่องใบหนึ่งมีลูกบอลทั้งหมด 15 ลูก โดยมีลูกบอล สีส้ม 1 ลูก, สีแดง 2 ลูก, 
สีน้ำเงิน 3 ลูก, สีเหลือง 4 ลูก, และ สีดำ 5 ลูกจะมีวิธีเรียงกี่วิธี

จงหาค่าดังต่อไปนี้
1.ได้หัวครั้งแรกและได้หัว 5 จาก 8 ครั้ง
ตอบ	A คือ เหตุการณ์ที่ได้หัวจากการโยนเหรียญครั้งแรก
		B คือ เหตุการณ์ที่ได้หัวจากการโยนเหรียญ 5 ครั้งจะได้ P(B) = 8C5 x 1/ 28 = 8
	P(A ∩ B) เหตุการณ์ที่ได้หัวจากครั้งแรกและได้หัวจากการโยนเหรียญ 5 ครั้ง
	ดังนั้น 	n(A∩B) = 7C4
		P(A∩B) = 7C4 / 28  = 5
		P(A|B) 	= P(A∩B) / P(B)
			= 5 / 8
			= 0.625

2. ได้หัวครั้งแรกและได้หัว 6 จาก 8 ครั้ง
	A คือ เหตุการณ์ที่ได้หัวจากการโยนเหรียญครั้งแรก
		B คือ เหตุการณ์ที่ได้หัวจากการโยนเหรียญ 6 ครั้งจะได้ P(B) = 8C6 x 1/ 28
	P(A ∩ B) เหตุการณ์ที่ได้หัวจากครั้งแรกและได้หัวจากการโยนเหรียญ 6 ครั้ง
	ดังนั้น 	n(A∩B) = 7C5
		P(A∩B) = 7C5 / 28  
		P(A|B) 	= P(A∩B) / P(B)
			=( 7C5 / 28  ) / (8C6 x 1/ 28)
			= 3/4
			=0.75

3. ได้หัวครั้งแรกและได้หัว 7 จาก 8 ครั้ง
A คือ เหตุการณ์ที่ได้หัวจากการโยนเหรียญครั้งแรก
		B คือ เหตุการณ์ที่ได้หัวจากการโยนเหรียญ 7 ครั้งจะได้ P(B) = 8C7 x 1/ 28
	P(A ∩ B) เหตุการณ์ที่ได้หัวจากครั้งแรกและได้หัวจากการโยนเหรียญ 7 ครั้ง
	ดังนั้น 	n(A∩B) = 7C6
		P(A∩B) = 7C6 / 28  
		P(A|B) 	= P(A∩B) / P(B)
			=( 7C6 / 28  ) / (8C7 x 1/ 28)
			= 7/8
			=0.875

4. ได้หัวครั้งแรกและได้หัว 8 จาก 8 ครั้ง
	A คือ เหตุการณ์ที่ได้หัวจากการโยนเหรียญครั้งแรก
		B คือ เหตุการณ์ที่ได้หัวจากการโยนเหรียญ 8 ครั้งจะได้ P(B) = 8C8 x 1/ 28
	P(A ∩ B) เหตุการณ์ที่ได้หัวจากครั้งแรกและได้หัวจากการโยนเหรียญ 8 ครั้ง
	ดังนั้น 	n(A∩B) = 7C7
		P(A∩B) = 7C7 / 28  
		P(A|B) 	= P(A∩B) / P(B)
			=( 7C7 / 28  ) / (8C8 x 1/ 28)
			= 1
			
5. ความน่าจะเป็นที่ได้หัวอย่างน้อย 5 ครั้ง P(A|B1∪ B2 ∪ B3 ∪ B4)
	B1  คือ เหตุการณ์ที่ได้หัว 5 จาก 8 ครั้งจะได้ P(B1) 8C5 x 1/ 28 
		B2  คือ เหตุการณ์ที่ได้หัว 6 จาก 8 ครั้งจะได้ P(B2) 8C6 x 1/ 28 
B3  คือ เหตุการณ์ที่ได้หัว 7 จาก 8 ครั้งจะได้ P(B3) 8C7 x 1/ 28 
B4  คือ เหตุการณ์ที่ได้หัว 8 จาก 8 ครั้งจะได้ P(B4) 8C8 x 1/ 28 
	P(A|B1∪ B2 ∪ B3 ∪ B4) เหตุการณ์ที่ได้หัวอย่างน้อย 5 ครั้ง
ดังนั้น	P(A|B1∪ B2 ∪ B3 ∪ B4) = P(B1)+P(B2)+P(B3)+P(B4)
				= (8C5+8C6+8C7+8C8) x 1/ 28 
				= (56+28+8+1)/256
				= 0.36328
